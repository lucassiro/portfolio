# %% [markdown]
# ### Referências
# 1 - https://towardsdatascience.com/efficient-image-segmentation-using-pytorch-part-1-89e8297a0923
# 2 - https://towardsdatascience.com/efficient-image-segmentation-using-pytorch-part-2-bed68cadd7c7
# 2.1 - https://github.com/dhruvbird/ml-notebooks/blob/main/pets_segmentation/oxford-iiit-pets-segmentation-using-pytorch-segnet-and-depth-wise-separable-convs.ipynb
# 3 - https://towardsdatascience.com/efficient-image-segmentation-using-pytorch-part-3-3534cf04fb89
# 3.1 - https://github.com/dhruvbird/ml-notebooks/blob/main/pets_segmentation/oxford-iiit-pets-segmentation-using-pytorch-segnet-and-depth-wise-separable-convs.ipynb
# 3.2 - https://github.com/dhruvbird/ml-notebooks/blob/main/pets_segmentation/types%20of%20convolutions.ipynb
# 4 - https://towardsdatascience.com/efficient-image-segmentation-using-pytorch-part-4-6c86da083432
# 4.1 - https://github.com/dhruvbird/ml-notebooks/blob/main/pets_segmentation/vision-transformer-for-oxford-iiit-pet-segmentatio.ipynb
#
# 5 - https://medium.com/mlearning-ai/vision-transformers-from-scratch-pytorch-a-step-by-step-guide-96c3313c2e0c
# 6 - https://towardsdatascience.com/implementing-segformer-in-pytorch-8f4705e2ed0e
# 7 - https://towardsdatascience.com/implementing-visualttransformer-in-pytorch-184f9f16f632
# 8 - https://theaisummer.com/vision-transformer/
# 9 - http://jalammar.github.io/illustrated-transformer/

# %% [markdown]
# # SegNet

# %% [markdown]
# ![image.png](attachment:image.png)
